# %%
x={
  "solotik50":150,
  "pantazol":250,
  "rapidus":300,
  "bayer":200
}  
g=0
d={}
class doctor:
  def __init__(self,ID=None,name=None,field=None) -> None:
    self.ID=ID
    self.name=name
    self.field=field
  def enterData(self,n):
    self.n=n
    global d
    for i in range(n):
     self.ID=int(input("please enter your id :  "))
     self.name=str(input("enter your name :  "))
     self.field=str(input("enter your field : "))
     d.update({self.ID:[self.ID,self.name,self.field]})
    return d  

     
  def showDoc(self,n):
    
      print(f"the id of the doctor  {n} is  :  {d[n][0]}")
      print(f"the name of the doctor  is :  {d[n][1]}")
      print(f"the field of the doctor  is:  {d[n][2]}")
      print("#################################################")
  def showDocAll(self,n):
    for i in range(n):
      print(f"the id of the doctor  {n}  :  {d[n][0]}")
      print(f"the name of the doctor  is :  {d[n][1]}")
      print(f"the field of the doctor  is:  {d[n][2]}")
      print("#################################################")

  def notes(self,notes):
    self.note=notes
    return self.note 
  def disclosed(self):
    dis=input("enter the name of the drug you want to search for")
    if dis in x:
     return (self.name,dis)  
    else:
      raise KeyError(f"dont found {self.dis} in system")
a={}
class patient(doctor):
  def __init__(self,ID1=None,name1=None,phone=None,address=None,medical_history=None ,ID=None, name=None, field=None) -> None:
    super().__init__(ID, name, field)
    self.ID1=ID1
    self.name1=name1
    self.phone=phone
    self.address=address
    self.medical_history=medical_history
  def enterData_patient(self,n):
    self.n=n
    global a
    for i in range(n):
     self.ID1=int(input("please enter your id : "))
     self.name1=str(input("enter your name : "))
     self.phone=str(input("enter your phone : "))
     self.address=str(input("enter your addres : "))
     self.medical_history=str(input("enter your medical_history  "))
     a.update({self.ID1:[self.ID1,self.name1,self.phone,self.address,self.medical_history]})
    return a   

  def show_data_patient(self,n):
    
    print(f"the id of patient is             : {a[n][0]} ")
    print(f"the name of patient is           : {a[n][1]} ")
    print(f"the phone of patient is          : {a[n][2]} ")
    print(f"the address of patient is        : {a[n][3]} ")
    print(f"the medical_history of patient is: {a[n][4]} ")
    print("#################################################")
  def show_data_patient_all(self,n):
    for i in range(n):
      print(f"the id of patient is             : {a[n][0]} ")
      print(f"the name of patient is           : {a[n][1]} ")
      print(f"the phone of patient is          : {a[n][2]} ")
      print(f"the address of patient is        : {a[n][3]} ")
      print(f"the medical_history of patient is: {a[n][4]} ")
      print("#################################################") 
    
  def updata(self,n) :
   x=int(input("if you want to do updata the medical_history enter 0 elif  do updata the notes about the patient enter 1 else you want updata both enter 2  "))

   if x==0:
    
    p=int(input("enter the id"))
    self.medical_history_new=str(input("enter the medical_history new"))
    a.update({p:[self.ID1,self.name1,self.phone,self.address,self.medical_history_new]})
    self.show_data_patient(n)


    
    
    
    
   elif x==1:
    
    
    z=input("please enter the new notes do you want updata it")
    self.notes(z)
   else:
    p=int(input("enter the id"))
    self.medical_history_new=input("enter the medical_history new")
    a.update({p:[self.ID1,self.name1,self.phone,self.address,self.medical_history_new]})
    z=input("please enter the new notes do you want updata it")
    self.notes(z)
    
    
    return a , self.notes(z)
    
    
  def disbursed(self,drug=None):
    self.drug=drug
    if drug in x:
      return (self.name1,self.drug)
    else:
      raise KeyError(f"dont found {self.drug} in system")
  def priceofdisbursed(self):
    
    global g
    global x
    
    t=int(input("nmber of drugs"))
    
    for i in range(t):
     self.drug=input("enter the name of the drug you want to search for")
     if self.drug in x:
        g+=x[self.drug]
    
     else:
      raise KeyError(f"dont found {self.drug} in system")
    return g   
    
    
class manager(patient):
  def __init__(self, ID1=None, name1=None, phone=None, address=None, medical_history=None) -> None:
    super().__init__(ID1, name1, phone, address, medical_history)
    
  
  def theprice(self):
      
      return f"the total price of drugs is : {g}" 
  def showall(self,n):
    try:
        for n in a:
          print(f"the id of patient is       : {a[n][0]} ")
          print(f"the name of patient is           : {a[n][1]} ")
          print(f"the phone of patient is          : {a[n][2]} ")
          print(f"the address of patient is        : {a[n][3]} ")
          print(f"the medical_history of patient is: {a[n][4]} ")
          print("#################################################")  
    except:  
        for n in d:
         print(f"the id of the doctor  {n}  :  {d[n][0]}")
         print(f"the name of the doctor  is :  {d[n][1]}")
         print(f"the field of the doctor  is:  {d[n][2]}")
         print("#################################################")
  def showall1(self,n):
     for n in a:
          print(f"the id of patient is       : {a[n][0]} ")
          print(f"the name of patient is           : {a[n][1]} ")
          print(f"the phone of patient is          : {a[n][2]} ")
          print(f"the address of patient is        : {a[n][3]} ")
          print(f"the medical_history of patient is: {a[n][4]} ")
          print("#################################################")      
     for n in d:
        print(f"the id of the doctor  {n}  :  {d[n][0]}")
        print(f"the name of the doctor  is :  {d[n][1]}")
        print(f"the field of the doctor  is:  {d[n][2]}")
        print("#################################################")
def user_inerface():
  z=int(input("if you want add the new doctor enter 1 , or you want add the new patient enter 2 , if you want add new doctor and patient enter 3"))
  if z==1:
    n=int(input("enter number of the doctor do you want add "))
    c=doctor()
    
    c.enterData(n)
    l=int(input("if you want showdata of the doc enter 1 ,if you dont want it enter any another number"))
    if l==1:
      w=int(input("enter your id to show data "))
      c.showDoc(w)
      
  elif z==2:
    q=patient()
    
    n=int(input("enter number of the patient do you want add "))
    q.enterData_patient(n)
    l=int(input("if you want showdata of the patient enter 1 ,if you dont want it enter any another number"))
    if l==1:
      w=int(input("enter your id to show data "))
      q.show_data_patient(w)
      r=int(input("if you want updata enter 1 "))
      if r==1:
          
       q.updata(n)
  elif z==3:
    n=int(input("enter number of the doctor do you want add "))
    c=doctor()
    
    c.enterData(n)
    l=int(input("if you want showdata of the doc enter 1 ,if you dont want it enter any another number"))
    if l==1:
      w=int(input("enter your id to show data "))
      c.showDoc(w)
    q=patient()
    
    n=int(input("enter number of the patient do you want add "))
    q.enterData_patient(n)
    l=int(input("if you want showdata of the patient enter 1 ,if you dont want it enter any another number"))
    if l==1:
      w=int(input("enter your id to show data "))
      q.show_data_patient(w)
    r=int(input("if you want updata enter 1 "))
    if r==1:
          q.updata(n)  
  u=int(input("if you want take the drugs enter 1 ,elif enter an anther number ")) 
  if u==1:
    q=patient()    
    q.priceofdisbursed()
    e=manager()
    y=e.theprice()
    print(y)
  else:
    pass  
  r=int(input("if you want print all data enter 1 ,elif enter an anther number "))
  if r==1:
    if z==1 or z==2:
     e.showall(n)
    else:
     e.showall1(n)   
user_inerface()
# Out:
# if you want add the new doctor enter 1 , or you want add the new patient enter 2 , if you want add new doctor and patient enter 33
# enter number of the doctor do you want add 1
# please enter your id :  1
# enter your name :
# enter your field : k
# if you want showdata of the doc enter 1 ,if you dont want it enter any another number0
# enter number of the patient do you want add 1
# please enter your id : 1
# enter your name : o
# enter your phone : l
# enter your addres : ll
# enter your medical_history  pppp
# if you want showdata of the patient enter 1 ,if you dont want it enter any another number0
# if you want updata enter 1 1
# if you want to do updata the medical_history enter 0 elif  do updata the notes about the patient enter 1 else you want updata both enter 2  0
# enter the id1
# enter the medical_history newooooo
# the id of patient is             : 1
# the name of patient is           : o
# the phone of patient is          : l
# the address of patient is        : ll
# ...
